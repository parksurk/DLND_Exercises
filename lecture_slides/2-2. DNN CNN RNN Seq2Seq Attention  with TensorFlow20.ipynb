# %%
from IPython.display import Image
Image(filename='./images/2-0-1-2_opening.jpg')

# %% [markdown]
# # Learning Plan

# %% [markdown]
# ### Lesson 2-2: DNN CNN RNN Seq2Seq Attention wih TensorFlow20
#
# #### 2-2-1 : Deep Learning brief introduction
# #### 2-2-2 : Shallow Neural Network Implementation
# #### 2-2-3 : Shallow Neural Network Training with Gradient Descent
# #### 2-2-4 : Deep Neural Network Training with Numerical Gradient
# #### 2-2-5 : Deep Neural Network Training with Backpropagation
# #### 2-2-6 : Convolution Neural Network Implementation
# #### 2-2-7 : Residual Network Implementation
# #### 2-2-8 : DenseNet Imprementation
# #### 2-2-9 : Recurrent Neural Network Imprementation
# #### 2-2-10 : Attention Neural Network
# #### 2-2-11 : Deep Learning Heuristic

# %% [markdown]
# # All materials references from ...
#
# - Stanford Univ. cs231n :http://cs231n.stanford.edu
# - Courera Andrew Ng's Deep Learning Specializaion : https://www.coursera.org/specializations/deep-learning
# - FastCampus DeepLearning AllinOne online : https://www.fastcampus.co.kr/data_online_deep/

# %% [markdown]
# # Lesson 2-2: DNN CNN RNN Seq2Seq Attention wih TensorFlow20
#
# ![](./images/2-2-0-0_rnn-opening.png)
#
# Reference to the Transformer paper(2017 NIPS)  [Attention Is All You Need](https://arxiv.org/abs/1706.03762)

# %% [markdown]
# ## 2-2-1 : Deep Learning brief introduction

# %% [markdown]
# ### 딥러닝의 이해

# %% [markdown]
# ![](./images/2-2-1-02.jpg)

# %% [markdown]
# ![](./images/2-2-1-03.jpg)

# %% [markdown]
# ![](./images/2-2-1-04.jpg)

# %% [markdown]
# ![](./images/2-2-1-05.jpg)

# %% [markdown]
# ![](./images/2-2-1-06.jpg)

# %% [markdown]
# ![](./images/2-2-1-07.jpg)

# %% [markdown]
# ![](./images/2-2-1-08.jpg)

# %% [markdown]
# ### 딥러닝의 역사

# %% [markdown]
# ![](./images/2-2-1-10.jpg)

# %% [markdown]
# ![](./images/2-2-1-11.jpg)

# %% [markdown]
# ![](./images/2-2-1-12.jpg)

# %% [markdown]
# ![](./images/2-2-1-13.jpg)

# %% [markdown]
# ![](./images/2-2-1-14.jpg)

# %% [markdown]
# ![](./images/2-2-1-15.jpg)

# %% [markdown]
# ![](./images/2-2-1-16.jpg)

# %% [markdown]
# ![](./images/2-2-1-17.jpg)

# %% [markdown]
# ![](./images/2-2-1-18.jpg)

# %% [markdown]
# ![](./images/2-2-1-19.jpg)

# %% [markdown]
# ![](./images/2-2-1-20.jpg)

# %% [markdown]
# ### 딥러닝의 현재

# %% [markdown]
# ![](./images/2-2-1-22.jpg)

# %% [markdown]
# ![](./images/2-2-1-23.jpg)

# %% [markdown]
# ![](./images/2-2-1-24.jpg)

# %% [markdown]
# ![](./images/2-2-1-25.jpg)

# %% [markdown]
# ![](./images/2-2-1-26.jpg)

# %% [markdown]
# ![](./images/2-2-1-27.jpg)

# %% [markdown]
# ![](./images/2-2-1-28.jpg)

# %% [markdown]
# ![](./images/2-2-1-29.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/01. DL Hands-on environment intro.ipynb">01. DL Hands-on environment intro.ipynb</a>

# %% [markdown]
# ## 2-2-2 : Shallow Neural Network Implementation

# %% [markdown]
# ### 얕은 신경망의 구조

# %% [markdown]
# ![](./images/2-2-2-02.jpg)

# %% [markdown]
# ![](./images/2-2-2-03.jpg)

# %% [markdown]
# ![](./images/2-2-2-04.jpg)

# %% [markdown]
# ![](./images/2-2-2-06.jpg)

# %% [markdown]
# ![](./images/2-2-2-07.jpg)

# %% [markdown]
# ### 얕은 신경망을 이용한 분류와 회귀

# %% [markdown]
# ![](./images/2-2-2-09.jpg)

# %% [markdown]
# ![](./images/2-2-2-10.jpg)

# %% [markdown]
# ![](./images/2-2-2-11.jpg)

# %% [markdown]
# ![](./images/2-2-2-12.jpg)

# %% [markdown]
# ![](./images/2-2-2-13.jpg)

# %% [markdown]
# ![](./images/2-2-2-14.jpg)

# %% [markdown]
# ### 얕은 신경망의 수식적 이해

# %% [markdown]
# ![](./images/2-2-2-16.jpg)

# %% [markdown]
# ![](./images/2-2-2-17.jpg)

# %% [markdown]
# ![](./images/2-2-2-18.jpg)

# %% [markdown]
# ![](./images/2-2-2-19.jpg)

# %% [markdown]
# ![](./images/2-2-2-20.jpg)

# %% [markdown]
# ![](./images/2-2-2-21.jpg)

# %% [markdown]
# ### 회귀 문제의 이해

# %% [markdown]
# ![](./images/2-2-2-23.jpg)

# %% [markdown]
# ![](./images/2-2-2-24.jpg)

# %% [markdown]
# ![](./images/2-2-2-25.jpg)

# %% [markdown]
# ![](./images/2-2-2-26.jpg)

# %% [markdown]
# ![](./images/2-2-2-27.jpg)

# %% [markdown]
# ![](./images/2-2-2-28.jpg)

# %% [markdown]
# ![](./images/2-2-2-29.jpg)

# %% [markdown]
# ### 이진 분류 문제

# %% [markdown]
# ![](./images/2-2-2-31.jpg)

# %% [markdown]
# ![](./images/2-2-2-32.jpg)

# %% [markdown]
# ![](./images/2-2-2-33.jpg)

# %% [markdown]
# ![](./images/2-2-2-34.jpg)

# %% [markdown]
# ![](./images/2-2-2-35.jpg)

# %% [markdown]
# ![](./images/2-2-2-36.jpg)

# %% [markdown]
# ![](./images/2-2-2-37.jpg)

# %% [markdown]
# ### 다중 분류 문제

# %% [markdown]
# ![](./images/2-2-2-39.jpg)

# %% [markdown]
# ![](./images/2-2-2-40.jpg)

# %% [markdown]
# ![](./images/2-2-2-41.jpg)

# %% [markdown]
# ![](./images/2-2-2-42.jpg)

# %% [markdown]
# ![](./images/2-2-2-43.jpg)

# %% [markdown]
# ![](./images/2-2-2-44.jpg)

# %% [markdown]
# ![](./images/2-2-2-45.jpg)

# %% [markdown]
# ![](./images/2-2-2-46.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/02. Shallow Neural Network implementation.ipynb">02. Shallow Neural Network implementation.ipynb</a>

# %% [markdown]
# ## 2-2-3 : Shallow Neural Network Training with Gradient Descent

# %% [markdown]
# ### 모델의 학습과 최적화 이론

# %% [markdown]
# ![](./images/2-2-3-02.jpg)

# %% [markdown]
# ![](./images/2-2-3-03.jpg)

# %% [markdown]
# ![](./images/2-2-3-04.jpg)

# %% [markdown]
# ![](./images/2-2-3-05.jpg)

# %% [markdown]
# ![](./images/2-2-3-06.jpg)

# %% [markdown]
# ![](./images/2-2-3-07.jpg)

# %% [markdown]
# ![](./images/2-2-3-08.jpg)

# %% [markdown]
# ![](./images/2-2-3-09.jpg)

# %% [markdown]
# ### 경사 하강 학습법

# %% [markdown]
# ![](./images/2-2-3-11.jpg)

# %% [markdown]
# ![](./images/2-2-3-12.jpg)

# %% [markdown]
# ![](./images/2-2-3-13.jpg)

# %% [markdown]
# ![](./images/2-2-3-14.jpg)

# %% [markdown]
# ![](./images/2-2-3-15.jpg)

# %% [markdown]
# ![](./images/2-2-3-16.jpg)

# %% [markdown]
# ### 최적화 이론과 수학적 표현

# %% [markdown]
# ![](./images/2-2-3-18.jpg)

# %% [markdown]
# ![](./images/2-2-3-19.jpg)

# %% [markdown]
# ![](./images/2-2-3-20.jpg)

# %% [markdown]
# ![](./images/2-2-3-21.jpg)

# %% [markdown]
# ![](./images/2-2-3-22.jpg)

# %% [markdown]
# ### 경사 하강 학습법

# %% [markdown]
# ![](./images/2-2-3-24.jpg)

# %% [markdown]
# ![](./images/2-2-3-25.jpg)

# %% [markdown]
# ![](./images/2-2-3-26.jpg)

# %% [markdown]
# ![](./images/2-2-3-27.jpg)

# %% [markdown]
# ![](./images/2-2-3-28.jpg)

# %% [markdown]
# ![](./images/2-2-3-30.jpg)

# %% [markdown]
# ![](./images/2-2-3-31.jpg)

# %% [markdown]
# ![](./images/2-2-3-32.jpg)

# %% [markdown]
# ![](./images/2-2-3-33.jpg)

# %% [markdown]
# ![](./images/2-2-3-34.jpg)

# %% [markdown]
# ![](./images/2-2-3-35.jpg)

# %% [markdown]
# ![](./images/2-2-3-36.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/03. Shallow Neural Network Training with Gradient Descent.ipynb">03. Shallow Neural Network Training with Gradient Descent.ipynb</a>

# %% [markdown]
# ## 2-2-4 : Deep Neural Network Training with Numerical Gradient

# %% [markdown]
# ### 심층 신경망의 구조

# %% [markdown]
# ![](./images/2-2-4-02.jpg)

# %% [markdown]
# ![](./images/2-2-4-03.jpg)

# %% [markdown]
# ![](./images/2-2-4-04.jpg)

# %% [markdown]
# ![](./images/2-2-4-05.jpg)

# %% [markdown]
# ![](./images/2-2-4-06.jpg)

# %% [markdown]
# ### 심층 신경망의 수학적 이해

# %% [markdown]
# ![](./images/2-2-4-08.jpg)

# %% [markdown]
# ![](./images/2-2-4-09.jpg)

# %% [markdown]
# ![](./images/2-2-4-10.jpg)

# %% [markdown]
# ![](./images/2-2-4-11.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/04. Deep Neural Network Training with Numerical Gradient.ipynb">04. Deep Neural Network Training with Numerical Gradient.ipynb</a>

# %% [markdown]
# ## 2-2-5 : Deep Neural Network Training with Backpropagation

# %% [markdown]
# ### 역전파 학습법의 개념

# %% [markdown]
# ![](./images/2-2-5-02.jpg)

# %% [markdown]
# ![](./images/2-2-5-03.jpg)

# %% [markdown]
# ![](./images/2-2-5-04.jpg)

# %% [markdown]
# ![](./images/2-2-5-05.jpg)

# %% [markdown]
# ![](./images/2-2-5-06.jpg)

# %% [markdown]
# ![](./images/2-2-5-07.jpg)

# %% [markdown]
# ![](./images/2-2-5-08.jpg)

# %% [markdown]
# ![](./images/2-2-5-09.jpg)

# %% [markdown]
# ![](./images/2-2-5-10.jpg)

# %% [markdown]
# ### 역전파 학습의 필요성

# %% [markdown]
# ![](./images/2-2-5-12.jpg)

# %% [markdown]
# ![](./images/2-2-5-13.jpg)

# %% [markdown]
# ![](./images/2-2-5-14.jpg)

# %% [markdown]
# ![](./images/2-2-5-15.jpg)

# %% [markdown]
# ![](./images/2-2-5-16.jpg)

# %% [markdown]
# ### 합성 함수와 연쇄 법칙

# %% [markdown]
# ![](./images/2-2-5-18.jpg)

# %% [markdown]
# ![](./images/2-2-5-19.jpg)

# %% [markdown]
# ![](./images/2-2-5-20.jpg)

# %% [markdown]
# ![](./images/2-2-5-21.jpg)

# %% [markdown]
# ### 역전파 학습법의 수식적 이해

# %% [markdown]
# ![](./images/2-2-5-23.jpg)

# %% [markdown]
# ![](./images/2-2-5-24.jpg)

# %% [markdown]
# ![](./images/2-2-5-25.jpg)

# %% [markdown]
# ![](./images/2-2-5-26.jpg)

# %% [markdown]
# ![](./images/2-2-5-28.jpg)

# %% [markdown]
# ![](./images/2-2-5-30.jpg)

# %% [markdown]
# ![](./images/2-2-5-31.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/05. Deep Neural Network Training with Backpropagation.ipynb">05. Deep Neural Network Training with Backpropagation.ipynb</a>

# %% [markdown]
# ## 2-2-6 : Convolution Neural Network Implementation

# %% [markdown]
# ### 합성곱 연산과 이미지 필터

# %% [markdown]
# ![](./images/2-2-6-02.jpg)

# %% [markdown]
# ![](./images/2-2-6-03.jpg)

# %% [markdown]
# ![](./images/2-2-6-04.jpg)

# %% [markdown]
# ![](./images/2-2-6-05.jpg)

# %% [markdown]
# ![](./images/2-2-6-06.jpg)

# %% [markdown]
# ![](./images/2-2-6-07.jpg)

# %% [markdown]
# ![](./images/2-2-6-08.jpg)

# %% [markdown]
# ![](./images/2-2-6-09.jpg)

# %% [markdown]
# ![](./images/2-2-6-10.jpg)

# %% [markdown]
# ![](./images/2-2-6-11.jpg)

# %% [markdown]
# ### 합성곱 계층

# %% [markdown]
# ![](./images/2-2-6-13.jpg)

# %% [markdown]
# ![](./images/2-2-6-14.jpg)

# %% [markdown]
# ![](./images/2-2-6-15.jpg)

# %% [markdown]
# ![](./images/2-2-6-16.jpg)

# %% [markdown]
# ![](./images/2-2-6-17.jpg)

# %% [markdown]
# ### 기본적인 합성곱 신경망

# %% [markdown]
# ![](./images/2-2-6-19.jpg)

# %% [markdown]
# ![](./images/2-2-6-20.jpg)

# %% [markdown]
# ![](./images/2-2-6-21.jpg)

# %% [markdown]
# ![](./images/2-2-6-22.jpg)

# %% [markdown]
# ![](./images/2-2-6-23.jpg)

# %% [markdown]
# ![](./images/2-2-6-24.jpg)

# %% [markdown]
# ![](./images/2-2-6-25.jpg)

# %% [markdown]
# ![](./images/2-2-6-26.jpg)

# %% [markdown]
# ![](./images/2-2-6-27.jpg)

# %% [markdown]
# ![](./images/2-2-6-28.jpg)

# %% [markdown]
# ![](./images/2-2-6-29.jpg)

# %% [markdown]
# ### 합성곱 신경망의 심화 이해

# %% [markdown]
# ![](./images/2-2-6-31.jpg)

# %% [markdown]
# ![](./images/2-2-6-32.jpg)

# %% [markdown]
# ![](./images/2-2-6-33.jpg)

# %% [markdown]
# ![](./images/2-2-6-34.jpg)

# %% [markdown]
# ![](./images/2-2-6-35.jpg)

# %% [markdown]
# ![](./images/2-2-6-36.jpg)

# %% [markdown]
# ![](./images/2-2-6-37.jpg)

# %% [markdown]
# ![](./images/2-2-6-38.jpg)

# %% [markdown]
# ### 배치 정규화

# %% [markdown]
# ![](./images/2-2-6-40.jpg)

# %% [markdown]
# ![](./images/2-2-6-41.jpg)

# %% [markdown]
# ![](./images/2-2-6-42.jpg)

# %% [markdown]
# ![](./images/2-2-6-44.jpg)

# %% [markdown]
# ![](./images/2-2-6-45.jpg)

# %% [markdown]
# ![](./images/2-2-6-46.jpg)

# %% [markdown]
# ![](./images/2-2-6-47.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/06. Basic Convolution Neural Network implementation.ipynb">06. Basic Convolution Neural Network implementation.ipynb</a>

# %% [markdown]
# ## 2-2-7 : Residual Network Implementation

# %% [markdown]
# ### 심화 합성곱 신경망

# %% [markdown]
# ![](./images/2-2-7-02.jpg)

# %% [markdown]
# ![](./images/2-2-7-03.jpg)

# %% [markdown]
# ![](./images/2-2-7-04.jpg)

# %% [markdown]
# ![](./images/2-2-7-05.jpg)

# %% [markdown]
# ![](./images/2-2-7-06.jpg)

# %% [markdown]
# ![](./images/2-2-7-07.jpg)

# %% [markdown]
# ![](./images/2-2-7-08.jpg)

# %% [markdown]
# ![](./images/2-2-7-09.jpg)

# %% [markdown]
# ![](./images/2-2-7-10.jpg)

# %% [markdown]
# ![](./images/2-2-7-11.jpg)

# %% [markdown]
# ![](./images/2-2-7-12.jpg)

# %% [markdown]
# ![](./images/2-2-7-13.jpg)

# %% [markdown]
# ![](./images/2-2-7-14.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/07. Residual Network Imprementation.ipynb">07. Residual Network Imprementation.ipynb</a>

# %% [markdown]
# ## 2-2-8 : DenseNet Imprementation

# %% [markdown]
# ![](./images/2-2-8-01.jpg)

# %% [markdown]
# ![](./images/2-2-8-02.jpg)

# %% [markdown]
# ![](./images/2-2-8-03.jpg)

# %% [markdown]
# ![](./images/2-2-8-04.jpg)

# %% [markdown]
# ![](./images/2-2-8-05.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/08. DenseNet Imprementation.ipynb">08. DenseNet Imprementation.ipynb</a>

# %% [markdown]
# ## 2-2-9 :Feature Visualization

# %% [markdown]
# ### 순차 데이터의 이해

# %% [markdown]
# ![](./images/2-2-9-02.jpg)

# %% [markdown]
# ![](./images/2-2-9-03.jpg)

# %% [markdown]
# ![](./images/2-2-9-04.jpg)

# %% [markdown]
# ![](./images/2-2-9-05.jpg)

# %% [markdown]
# ![](./images/2-2-9-06.jpg)

# %% [markdown]
# ![](./images/2-2-9-07.jpg)

# %% [markdown]
# ### 기본적인 순환 신경망

# %% [markdown]
# ![](./images/2-2-9-09.jpg)

# %% [markdown]
# ![](./images/2-2-9-10.jpg)

# %% [markdown]
# ![](./images/2-2-9-11.jpg)

# %% [markdown]
# ![](./images/2-2-9-12.jpg)

# %% [markdown]
# ![](./images/2-2-9-13.jpg)

# %% [markdown]
# ### 심화 순환 신경망

# %% [markdown]
# ![](./images/2-2-9-15.jpg)

# %% [markdown]
# ![](./images/2-2-9-16.jpg)

# %% [markdown]
# ![](./images/2-2-9-17.jpg)

# %% [markdown]
# ![](./images/2-2-9-18.jpg)

# %% [markdown]
# ![](./images/2-2-9-20.jpg)

# %% [markdown]
# ![](./images/2-2-9-21.jpg)

# %% [markdown]
# ![](./images/2-2-9-22.jpg)

# %% [markdown]
# ![](./images/2-2-9-23.jpg)

# %% [markdown]
# ![](./images/2-2-9-24.jpg)

# %% [markdown]
# ![](./images/2-2-9-25.jpg)

# %% [markdown]
# ![](./images/2-2-9-26.jpg)

# %% [markdown]
# ### 시간펼침 역전파 학습법

# %% [markdown]
# ![](./images/2-2-9-28.jpg)

# %% [markdown]
# ![](./images/2-2-9-29.jpg)

# %% [markdown]
# ![](./images/2-2-9-30.jpg)

# %% [markdown]
# ![](./images/2-2-9-31.jpg)

# %% [markdown]
# ![](./images/2-2-9-32.jpg)

# %% [markdown]
# ![](./images/2-2-9-33.jpg)

# %% [markdown]
# ![](./images/2-2-9-34.jpg)

# %% [markdown]
# ![](./images/2-2-9-35.jpg)

# %% [markdown]
# ### 심화 순환 신경망의 수식적 이해

# %% [markdown]
# ![](./images/2-2-9-37.jpg)

# %% [markdown]
# ![](./images/2-2-9-38.jpg)

# %% [markdown]
# ![](./images/2-2-9-39.jpg)

# %% [markdown]
# ![](./images/2-2-9-40.jpg)

# %% [markdown]
# ![](./images/2-2-9-41.jpg)

# %% [markdown]
# ![](./images/2-2-9-42.jpg)

# %% [markdown]
# ![](./images/2-2-9-43.jpg)

# %% [markdown]
# ![](./images/2-2-9-44.jpg)

# %% [markdown]
# ![](./images/2-2-9-45.jpg)

# %% [markdown]
# ![](./images/2-2-9-46.jpg)

# %% [markdown]
# ![](./images/2-2-9-47.jpg)

# %% [markdown]
# ![](./images/2-2-9-48.jpg)

# %% [markdown]
# ![](./images/2-2-9-49.jpg)

# %% [markdown]
# ![](./images/2-2-9-50.jpg)

# %% [markdown]
# ![](./images/2-2-9-51.jpg)

# %% [markdown]
# ### 순차 신경망에서 Tensor의 이해

# %% [markdown]
# ![](./images/2-2-9-53.jpg)

# %% [markdown]
# ![](./images/2-2-9-54.jpg)

# %% [markdown]
# ![](./images/2-2-9-55.jpg)

# %% [markdown]
# ![](./images/2-2-9-56.jpg)

# %% [markdown]
# ![](./images/2-2-9-57.jpg)

# %% [markdown]
# ![](./images/2-2-9-58.jpg)

# %% [markdown]
# ### 순환 신경망의 학습법

# %% [markdown]
# ![](./images/2-2-9-60.jpg)

# %% [markdown]
# ![](./images/2-2-9-61.jpg)

# %% [markdown]
# ![](./images/2-2-9-62.jpg)

# %% [markdown]
# ![](./images/2-2-9-63.jpg)

# %% [markdown]
# ![](./images/2-2-9-64.jpg)

# %% [markdown]
# ![](./images/2-2-9-65.jpg)

# %% [markdown]
# ![](./images/2-2-9-66.jpg)

# %% [markdown]
# ![](./images/2-2-9-67.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/09. Recurrent Neural Network Implementation.ipynb">09. Recurrent Neural Network Implementation.ipynb</a>

# %% [markdown]
# ## 2-2-10 : Attention Neural Network

# %% [markdown]
# ### Attention 기법의 이해

# %% [markdown]
# ![](./images/2-2-10-02.jpg)

# %% [markdown]
# ![](./images/2-2-10-03.jpg)

# %% [markdown]
# ![](./images/2-2-10-04.jpg)

# %% [markdown]
# ![](./images/2-2-10-05.jpg)

# %% [markdown]
# ![](./images/2-2-10-06.jpg)

# %% [markdown]
# ![](./images/2-2-10-07.jpg)

# %% [markdown]
# ### Attention 신경망

# %% [markdown]
# ![](./images/2-2-10-09.jpg)

# %% [markdown]
# ![](./images/2-2-10-10.jpg)

# %% [markdown]
# ![](./images/2-2-10-11.jpg)

# %% [markdown]
# ![](./images/2-2-10-12.jpg)

# %% [markdown]
# ![](./images/2-2-10-13.jpg)

# %% [markdown]
# ![](./images/2-2-10-14.jpg)

# %% [markdown]
# ![](./images/2-2-10-15.jpg)

# %% [markdown]
# ![](./images/2-2-10-16.jpg)

# %% [markdown]
# ![](./images/2-2-10-17.jpg)

# %% [markdown]
# ![](./images/2-2-10-18.jpg)

# %% [markdown]
# ![](./images/2-2-10-19.jpg)

# %% [markdown]
# ![](./images/2-2-10-20.jpg)

# %% [markdown]
# ![](./images/2-2-10-21.jpg)

# %% [markdown]
# ![](./images/2-2-10-22.jpg)

# %% [markdown]
# ![](./images/2-2-10-23.jpg)

# %% [markdown]
# ![](./images/2-2-10-24.jpg)

# %% [markdown]
# ![](./images/2-2-10-25.jpg)

# %% [markdown]
# ![](./images/2-2-10-26.jpg)

# %% [markdown]
# ![](./images/2-2-10-27.jpg)

# %% [markdown]
# ![](./images/2-2-10-28.jpg)

# %% [markdown]
# ![](./images/2-2-10-29.jpg)

# %% [markdown]
# ![](./images/2-2-10-30.jpg)

# %% [markdown]
# ### Attention 신경망의 수식적 이해

# %% [markdown]
# ![](./images/2-2-10-32.jpg)

# %% [markdown]
# ![](./images/2-2-10-33.jpg)

# %% [markdown]
# ![](./images/2-2-10-34.jpg)

# %% [markdown]
# ![](./images/2-2-10-35.jpg)

# %% [markdown]
# ![](./images/2-2-10-36.jpg)

# %% [markdown]
# ![](./images/2-2-10-37.jpg)

# %% [markdown]
# ![](./images/2-2-10-38.jpg)

# %% [markdown]
# ![](./images/2-2-10-39.jpg)

# %% [markdown]
# ![](./images/2-2-10-40.jpg)

# %% [markdown]
# ![](./images/2-2-10-41.jpg)

# %% [markdown]
# ![](./images/2-2-10-42.jpg)

# %% [markdown]
# ![](./images/2-2-10-43.jpg)

# %% [markdown]
# ![](./images/2-2-10-44.jpg)

# %% [markdown]
# ![](./images/2-2-10-45.jpg)

# %% [markdown]
# ![](./images/2-2-10-46.jpg)

# %% [markdown]
# ![](./images/2-2-10-47.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/10. Attention Neural Network Implementation.ipynb">10. Attention Neural Network Implementation.ipynb</a>

# %% [markdown]
# ## 2-2-11 : Deep Learning Heuristic

# %% [markdown]
# ### 과적합의 해결

# %% [markdown]
# ![](./images/2-2-11-02.jpg)

# %% [markdown]
# ![](./images/2-2-11-03.jpg)

# %% [markdown]
# ![](./images/2-2-11-04.jpg)

# %% [markdown]
# ![](./images/2-2-11-05.jpg)

# %% [markdown]
# ![](./images/2-2-11-06.jpg)

# %% [markdown]
# ![](./images/2-2-11-07.jpg)

# %% [markdown]
# ![](./images/2-2-11-08.jpg)

# %% [markdown]
# ![](./images/2-2-11-09.jpg)

# %% [markdown]
# ![](./images/2-2-11-10.jpg)

# %% [markdown]
# ### 추가적인 손실 함수

# %% [markdown]
# ![](./images/2-2-11-12.jpg)

# %% [markdown]
# ![](./images/2-2-11-13.jpg)

# %% [markdown]
# ![](./images/2-2-11-14.jpg)

# %% [markdown]
# ![](./images/2-2-11-15.jpg)

# %% [markdown]
# ![](./images/2-2-11-16.jpg)

# %% [markdown]
# ![](./images/2-2-11-17.jpg)

# %% [markdown]
# ### 데이터 증강 기법

# %% [markdown]
# ![](./images/2-2-11-19.jpg)

# %% [markdown]
# ![](./images/2-2-11-20.jpg)

# %% [markdown]
# ![](./images/2-2-11-21.jpg)

# %% [markdown]
# ![](./images/2-2-11-22.jpg)

# %% [markdown]
# ![](./images/2-2-11-23.jpg)

# %% [markdown]
# ![](./images/2-2-11-24.jpg)

# %% [markdown]
# ![](./images/2-2-11-25.jpg)

# %% [markdown]
# ![](./images/2-2-11-26.jpg)

# %% [markdown]
# ### 배치 정규화와 변형 기법들

# %% [markdown]
# ![](./images/2-2-11-28.jpg)

# %% [markdown]
# ![](./images/2-2-11-29.jpg)

# %% [markdown]
# ![](./images/2-2-11-30.jpg)

# %% [markdown]
# ![](./images/2-2-11-31.jpg)

# %% [markdown]
# ![](./images/2-2-11-32.jpg)

# %% [markdown]
# ![](./images/2-2-11-33.jpg)

# %% [markdown]
# ![](./images/2-2-11-34.jpg)

# %% [markdown]
# ![](./images/2-2-11-35.jpg)

# %% [markdown]
# ![](./images/2-2-11-36.jpg)

# %% [markdown]
# ![](./images/2-2-11-37.jpg)

# %% [markdown]
# ![](./images/2-2-11-38.jpg)

# %% [markdown]
# ![](./images/2-2-11-39.jpg)

# %% [markdown]
# ![](./images/2-2-11-40.jpg)

# %% [markdown]
# ### SMOTE 알고리즘

# %% [markdown]
# ![](./images/2-2-11-42.jpg)

# %% [markdown]
# ![](./images/2-2-11-43.jpg)

# %% [markdown]
# ![](./images/2-2-11-44.jpg)

# %% [markdown]
# ![](./images/2-2-11-45.jpg)

# %% [markdown]
# ![](./images/2-2-11-46.jpg)

# %% [markdown]
# ### 정규화 기법의 이해

# %% [markdown]
# ![](./images/2-2-11-48.jpg)

# %% [markdown]
# ![](./images/2-2-11-49.jpg)

# %% [markdown]
# ![](./images/2-2-11-50.jpg)

# %% [markdown]
# ![](./images/2-2-11-51.jpg)

# %% [markdown]
# ![](./images/2-2-11-52.jpg)

# %% [markdown]
# ![](./images/2-2-11-53.jpg)

# %% [markdown]
# ![](./images/2-2-11-54.jpg)

# %% [markdown]
# ![](./images/2-2-11-55.jpg)

# %% [markdown]
# ![](./images/2-2-11-56.jpg)

# %% [markdown]
# ![](./images/2-2-11-57.jpg)

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/11. Deep Learning Heuristic with Overfitting.ipynb">11. Deep Learning Heuristic with Overfitting.ipynb</a>

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/12. Deep Learning Heuristic with Underfitting.ipynb">12. Deep Learning Heuristic with Underfitting.ipynb</a>

# %% [markdown]
# ### [Hands-on]
#
# <a href="../RNN_TF20/13. Deep Learning Heuristic with Imbalance Dataset.ipynb">13. Deep Learning Heuristic with Imbalance Dataset.ipynb</a>
