# %%
from IPython.display import Image
Image(filename='./images/0-0-1-1_opening.jpg')

# %% [markdown]
# # Learning Plan

# %% [markdown]
# ### Lesson 0-1 : Prerequisites 1 - Python
#
# ### Lesson 0-2 : Prerequisites 2 - Jupyter Notebook
#
# ### Lesson 1-3 : Prerequisites 3 - Linear Algebra

# %% [markdown]
# ### Lesson 0-4 : Prerequisites 4 - Numpy
#
# ### Lesson 0-5 : Prerequisites 5 - Visualization

# %% [markdown]
# # Lesson 0-5: Prerequisites4 : Visualization

# %% [markdown]
# # 0-5-1 : Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')  # cumsum은 random하게 생성된 값들의 누적

plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1, 2, 1)
plt.subplot(122)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
plt.subplot(2, 2, 1)
plt.plot(np.random.randn(50).cumsum(), 'k--')
plt.subplot(2, 2, 2)
plt.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
plt.subplot(2, 2, 3)
plt.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
x = np.arange(30)
y = np.arange(30) + 3 * np.random.randn(30)

# %%
plt.plot(x, y, 'g--')
plt.show()

# %%
plt.plot(x, y, 'g+')
plt.show()

# %%
plt.plot(x, y, 'b.')
plt.show()

# %%
# 검은색은 k
plt.plot(x, y, 'k.')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(10, 10))
plt.plot(x, y, 'k.')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(x, y, 'g--')
plt.subplot(2, 2, 2)
plt.plot(x, y, 'k.')
plt.subplot(2, 2, 3)
plt.plot(x, y, 'b.')
plt.show()

# %% [markdown]
# - 비율 조절

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plt.plot(x, y, 'g--')
plt.subplot(2, 2, 2)
plt.plot(x, y, 'k.')
plt.subplot(2, 2, 3)
plt.plot(x, y, 'b.')
plt.show()

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', 
         label='steps-post')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Matplotlib Plot')
plt.xlabel('Stages')
plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.plot(np.random.randn(1000).cumsum(), 
        'k', label='one')
plt.plot(np.random.randn(1000).cumsum(), 
        'k--', label='two')
plt.plot(np.random.randn(1000).cumsum(), 
        'k.', label='three')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig("fig_saved.svg")

# %% [markdown]
# # 0-5-2 : Image Visualization

# %% [markdown]
# ## package 불러오기

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 이미지 파일 열기
# - opencv로도 이미지 파일을  열 수 있지만, shape 순서가 바뀜.
# - PIL은 shape가 바뀌짐 않음.

# %%
path = './images/0-5-0-1_dog.jpg'  # 절대경로로 'C:/Workspace/Fast Campus/source/dog.jpg'로 줄 수 있음

image_pil = Image.open(path)
image = np.array(image_pil)

# %% [markdown]
# ## 이미지 들여다 보기
# - 이미지를 열기 전에 shape 및 min, max를 통해서 이미지의 range 확인 필요

# %%
image.shape
# Out:
# (734, 1100, 3)

# %%
np.max(image), np.min(image)
# Out:
# (255, 0)

# %% [markdown]
# ## 그래프로 시각화 하기

# %%
plt.hist(image.ravel(), 256, [0,256])
plt.show()

# %% [markdown]
# ## 그림 나타내기

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ## 이미지 흑백으로 열기

# %%
image_bw = image_pil.convert('L')
image_bw = np.array(image_bw)
image_bw.shape
# Out:
# (734, 1100)

# %% [markdown]
# ## 흑백 이미지 열기

# %%
# 2개의 차원일 때는 gray scale로 열림
plt.imshow(image_bw)
plt.show()

# %% [markdown]
# ## 다른 색상으로 cmap 표현하기
#
# ### gray scale

# %%
plt.imshow(image_bw, cmap='gray')
plt.show()

# %% [markdown]
# ### RdBu

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %% [markdown]
# ### jet

# %%
plt.imshow(image_bw, 'jet')
plt.show()

# %% [markdown]
# ### Colorbar 추가하기

# %%
plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ## 이미지 설정

# %%
plt.figure(figsize=(10, 20))
plt.imshow(image)
plt.show()

# %% [markdown]
# ## 이미지에 제목 추가

# %%
plt.title("Tiger")
plt.imshow(image)
plt.show()

# %% [markdown]
# ## 두번째 이미지 열기

# %%
path = './images/0-5-0-2_cat.jpg'

image_pil = Image.open(path)
cat_image = np.array(image_pil)

# %% [markdown]
# ## 두번쨰 이미지를 첫번째 이미지 모양에 맞추기

# %%
cat_image.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(cat_image)
plt.show()

# %% [markdown]
# ## 두번째 이미지 합치기 위한 준비

# %%
# !pip install opencv-python # opencv 설치

# %%
import cv2

cat_image = cv2.resize(cat_image, \
                       (image.shape[1], image.shape[0]))

image.shape
# Out:
# (734, 1100, 3)

# %%
cat_image.shape
# Out:
# (734, 1100, 3)

# %% [markdown]
# ## Image 합치기

# %%
plt.imshow(image, alpha=0.8)
plt.imshow(cat_image, alpha=0.5)
plt.show()

# %% [markdown]
# ## Subplot

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.imshow(image)
plt.subplot(2, 2, 2)
plt.imshow(cat_image)
plt.subplot(2, 2, 3)
plt.imshow(image_bw, 'gray')
plt.show()
